# %%
from PIL import Image

# %%
import numpy as np

# %%
bw=Image.open('./data/frog.png').convert("L")

# %%
arr=np.array(bw)

# %%
arr.dtype=np.float64

# %%
import apple

# %%
conv=apple.jit('([((+)/* 0 (x::Arr (7`Cons`7`Cons`Nil) float))%ℝ(:x)] ⨳ {7,7})')

# %%
max=apple.jit('([(⋉)/* _10000000.0 (x::M float)]⨳ {7,7})')

# %%
blur=apple.f(conv,arr)

# %%
blur.dtype=np.uint8

# %%
Image.fromarray(blur)
# Out:
# <PIL.Image.Image image mode=L size=352x294>

# %%
arr.dtype=np.uint8

# %%
Image.fromarray(arr)
# Out:
# <PIL.Image.Image image mode=L size=400x300>
