# %%
from PIL import Image; import numpy as np

# %%
bw=Image.open('./data/frog.png').convert("L")

# %%
arr=np.array(bw).astype(np.float64)

# %%
import apple

# %%
conv=apple.jit('([((+)/* 0 (x::Arr (7 × 7) float))%ℝ(:x)] ⨳ {7,7})')

# %%
# %timeit apple.f(conv,arr)
# Out:
# 6.74 ms ± 8.21 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
blur=apple.f(conv,arr)

# %%
display(Image.fromarray(blur).convert("RGB"))
# Out:
# <PIL.Image.Image image mode=RGB size=394x294>
