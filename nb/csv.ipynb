# %%
import pandas as pd

# %%
ft=pd.read_csv('data/food-prices.csv')

# %%
price_series=ft[ft['Series_title_1']=='Apples, 1kg']['Data_value'].to_numpy()

# %%
import apple

# %%
inflation=apple.jit("[(-1)'(%)\\~x]")

# %%
apple.f(inflation,price_series)
# Out:
# array([ 0.06349206,  0.06965174,  0.05116279,  0.16371681,  0.0608365 ,
#         0.17921147,  0.18237082, -0.26735219, -0.22105263, -0.09009009,
#        -0.06435644,  0.        ,  0.04761905,  0.06565657,  0.00947867,
#         0.02347418,  0.16972477,  0.27058824,  0.04012346, -0.21958457,
#        -0.23954373,  0.025     , -0.0195122 ,  0.13432836,  0.10964912,
#         0.04347826,  0.05681818,  0.11827957,  0.17628205,  0.22070845,
#        -0.11383929, -0.27455919, -0.16666667, -0.0625    , -0.00444444,
#         0.08928571,  0.        ,  0.00409836,  0.06122449,  0.00769231,
#         0.08015267,  0.17667845,  0.07207207, -0.26610644, -0.19465649,
#        -0.01895735,  0.0531401 , -0.02752294,  0.08490566,  0.07391304,
#        -0.00809717,  0.12653061,  0.07608696,  0.14141414,  0.08849558,
#        -0.21138211, -0.25429553,  0.03225806, -0.01785714,  0.09545455,
#        -0.02489627,  0.04255319,  0.03673469,  0.08267717,  0.01454545,
# ...
