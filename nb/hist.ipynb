# %%
import apple

# %%
import matplotlib.pyplot as plt

# %%
xs=apple.apple('{: (gen. 0 [cos.(2*𝜋*𝔯 0 1)*√(_2*_.(𝔯 0 1))] 100)')

# %%
plt.hist(xs)
# Out:
# (array([ 2.,  2.,  5., 17., 21., 21., 19.,  7.,  3.,  2.]),
#  array([-2.83699632, -2.28335413, -1.72971194, -1.17606975, -0.62242756,
#         -0.06878537,  0.48485682,  1.03849901,  1.5921412 ,  2.14578338,
#          2.69942557]),
#  <BarContainer object of 10 artists>)
