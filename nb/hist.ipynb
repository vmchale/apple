# %%
import apple

# %%
import matplotlib.pyplot as plt

# %%
xs=apple.f(apple.jit('[cos.(2*𝜋*x)*√(_2*_.y)]`((𝔯 0 1)::Vec 1000 float) (𝔯 0 1)'))

# %%
plt.hist(xs)
# Out:
# (array([  8.,  23.,  72., 150., 216., 231., 157.,  92.,  40.,  11.]),
#  array([-3.0293432 , -2.43948853, -1.84963385, -1.25977918, -0.6699245 ,
#         -0.08006983,  0.50978484,  1.09963952,  1.68949419,  2.27934887,
#          2.86920354]),
#  <BarContainer object of 10 artists>)
