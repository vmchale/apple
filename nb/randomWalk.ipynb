# %%
import apple

# %%
random_walk=apple.jit('(+)Λ ((𝔯 _1 1) :: Vec 200 int)')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(apple.f(random_walk))

# %%
gaussian_walk=apple.jit("(+)Λ ([cos.(2*𝜋*x)*√(_2*_.y)]`((𝔯 0 1)::Vec 100 float) (𝔯 0 1))")

# %%
plt.plot(apple.f(gaussian_walk))
