# %%
import apple_math

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
bessel1=lambda x: apple_math.bessel1(1,x)

# %%
bessel_np=np.vectorize(bessel1)

# %%
xs=np.arange(0,20,0.05)

# %%
plt.plot(bessel_np(xs))
# Out:
# /home/vanessa/.local/lib/python3.11/site-packages/numpy/lib/function_base.py:2412: RuntimeWarning: invalid value encountered in <lambda> (vectorized)
#   outputs = ufunc(*inputs)
